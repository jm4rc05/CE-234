# %%
LIMITE = 5
_fila = [0] * LIMITE
_frente = 0
_retaguarda = 0

def size():
    return (LIMITE - _frente + _retaguarda) % LIMITE

def isEmpty():
    return _retaguarda == _frente

def first():
    if isEmpty():
        print(f"Fila vazia ({_retaguarda}, _{_frente})")
    else:
        return _fila[_frente]

def enqueue(v):
    global _retaguarda
    print(f'enqueue({v})')
    if size() == LIMITE - 1:
        print(f"Fila cheia ({size()})")
    else:
        _fila[_retaguarda] = v
        _retaguarda = (_retaguarda + 1) % LIMITE

def dequeue():
    global _frente
    if isEmpty():
        print(f"Fila vazia ({_retaguarda}, _{bottom})")
    else:
        _fila[_frente] = 0
        print(f'dequeue: {_frente}')
        _frente = (_frente + 1) % LIMITE

def show():
    for i in reversed(range(LIMITE)):
        print(f'({i}): {_fila[i]}')
    if isEmpty():
        print('Vazia')
        
    print(f'frente    : {_frente}')
    print(f'retaguarda: {_retaguarda}')

    print('\n')

enqueue(1)
show()

enqueue(2)
show()

dequeue()
show()

enqueue(3)
show()

enqueue(4)
show()

dequeue()
show()

enqueue(-1)
show()

enqueue(-2)
show()

dequeue()
show()

enqueue(-3)
show()

enqueue(-4)
show()

for i in range(4):
    dequeue()
    show()
# Out:
# enqueue(1)
# (4): 0
# (3): 0
# (2): 0
# (1): 0
# (0): 1
# frente    : 0
# retaguarda: 1
#
#
# enqueue(2)
# (4): 0
# (3): 0
# (2): 0
# (1): 2
# (0): 1
# frente    : 0
# retaguarda: 2
#
#
# dequeue: 0
# (4): 0
# (3): 0
# (2): 0
# (1): 2
# (0): 0
# frente    : 1
# retaguarda: 2
#
#
# enqueue(3)
# (4): 0
# (3): 0
# (2): 3
# (1): 2
# (0): 0
# frente    : 1
# retaguarda: 3
#
#
# enqueue(4)
# (4): 0
# (3): 4
# (2): 3
# (1): 2
# (0): 0
# frente    : 1
# retaguarda: 4
#
#
# dequeue: 1
# (4): 0
# (3): 4
# (2): 3
# (1): 0
# (0): 0
# frente    : 2
# retaguarda: 4
#
#
# enqueue(-1)
# (4): -1
# (3): 4
# (2): 3
# (1): 0
# (0): 0
# frente    : 2
# retaguarda: 0
#
#
# enqueue(-2)
# (4): -1
# (3): 4
# (2): 3
# (1): 0
# (0): -2
# frente    : 2
# retaguarda: 1
#
#
# dequeue: 2
# (4): -1
# (3): 4
# (2): 0
# (1): 0
# (0): -2
# frente    : 3
# retaguarda: 1
#
#
# enqueue(-3)
# (4): -1
# (3): 4
# (2): 0
# (1): -3
# (0): -2
# frente    : 3
# retaguarda: 2
#
#
# enqueue(-4)
# Fila cheia (4)
# (4): -1
# ...

# %% [markdown]
# > End
